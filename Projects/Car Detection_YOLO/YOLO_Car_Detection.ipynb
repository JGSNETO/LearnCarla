# %%
import cv2
from ultralytics import YOLO
import carla
import numpy as np
import matplotlib.pyplot as plt
# Out:
# WARNING  Python>=3.10 is required, but Python==3.8.0 is currently installed
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\jgsnt\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Load YOLOv8 model
model = YOLO("yolov8n.pt")

# %%
client = carla.Client('localhost', 2000)

# %%
world = client.get_world()

# %%
spawn_points = world.get_map().get_spawn_points()

# %%
bp_lib = world.get_blueprint_library()

for vehicle in bp_lib.filter('vehicle'):
    print(vehicle.id)
# Out:
# vehicle.audi.a2
# vehicle.nissan.micra
# vehicle.audi.tt
# vehicle.mercedes.coupe_2020
# vehicle.bmw.grandtourer
# vehicle.harley-davidson.low_rider
# vehicle.ford.ambulance
# vehicle.micro.microlino
# vehicle.carlamotors.firetruck
# vehicle.carlamotors.carlacola
# vehicle.carlamotors.european_hgv
# vehicle.ford.mustang
# vehicle.chevrolet.impala
# vehicle.lincoln.mkz_2020
# vehicle.citroen.c3
# vehicle.dodge.charger_police
# vehicle.nissan.patrol
# vehicle.jeep.wrangler_rubicon
# vehicle.mini.cooper_s
# vehicle.mercedes.coupe
# vehicle.dodge.charger_2020
# vehicle.ford.crown
# vehicle.seat.leon
# vehicle.toyota.prius
# vehicle.yamaha.yzf
# vehicle.kawasaki.ninja
# vehicle.bh.crossbike
# vehicle.mitsubishi.fusorosa
# vehicle.tesla.model3
# vehicle.gazelle.omafiets
# vehicle.tesla.cybertruck
# vehicle.diamondback.century
# vehicle.mercedes.sprinter
# vehicle.audi.etron
# vehicle.volkswagen.t2
# vehicle.lincoln.mkz_2017
# vehicle.dodge.charger_police_2020
# vehicle.vespa.zx125
# vehicle.mini.cooper_s_2021
# vehicle.nissan.patrol_2021
# vehicle.volkswagen.t2_2021

# %%
vehicle_bp = world.get_blueprint_library().filter('*cybertruck*')
start_point = spawn_points[0]
vehicle = world.try_spawn_actor(vehicle_bp[0], start_point)

# %%
# Camera Pos
CAMERA_POS_Z = 3
CAMERA_POS_X = 0

camera_bp = world.get_blueprint_library().find('sensor.camera.rgb')
camera_bp.set_attribute('image_size_x', '650')
camera_bp.set_attribute('image_size_y', '360')

camera_init_trans = carla.Transform(carla.Location(z=CAMERA_POS_Z, x = CAMERA_POS_X)) # Define the camera initial position and orientation
camera = world.spawn_actor(camera_bp, camera_init_trans, attach_to = vehicle) # Add the camera into the simulation

def camera_callback(image, data_dict): # Process each frame of data from the camera. 
    data_dict['image'] = np.reshape(np.copy(image.raw_data), (image.height, image.width, 4))
'''
 Retrieve the camera resolution that we set earlier and convert it to an integer so it can be used to initialize an array.
'''
image_w = camera_bp.get_attribute('image_size_x').as_int() 
image_h = camera_bp.get_attribute('image_size_y').as_int()
'''
Create a data structure (camera_data) to store the camera image data in a format that's easily accessible and modifiable during the simulation. 
'''
camera_data = {'image' : np.zeros((image_h, image_w,4))}
camera.listen(lambda image: camera_callback(image, camera_data)) # Open live stream from the camera

# %%
vehicle.set_autopilot(True)

# %%
while True:
    world.tick()
    if cv2.waitKey(1) == ord('q'):
        quit = True
        break
    image = camera_data['image']
    gray_frame = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray_frame_3ch = cv2.cvtColor(gray_frame, cv2.COLOR_GRAY2BGR)
    # Performs inference on the current frame
    results = model(gray_frame_3ch)

    # Filter results for cars only)
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls)
            if class_id == 2: # Class ID 2 is 'car' in COCO
                x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())  # Get bounding box coordinates
                confidence = box.conf[0] # Confidence score
                # Draw the bouding vox aroung the detected car
                cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Green box
                label = f'Car {confidence:.2f}'
                cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    cv2.imshow('Car detecion Camera', image)

cv2.destroyAllWindows()
camera.stop()
for actor in world.get_actors().filter('*vehicle*'):
    actor.destroy()
for sensor in world.get_actors().filter('*sensor*'):
    sensor.destroy()
# Out:
# 0: 384x640 (no detections), 118.9ms
# Speed: 7.9ms preprocess, 118.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.1ms
# Speed: 4.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.9ms
# Speed: 2.5ms preprocess, 48.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.4ms
# Speed: 2.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.2ms
# Speed: 3.0ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.5ms
# Speed: 2.3ms preprocess, 58.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.8ms
# Speed: 1.5ms preprocess, 54.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 56.3ms
# Speed: 1.0ms preprocess, 56.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.4ms
# Speed: 1.7ms preprocess, 48.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 50.2ms
# Speed: 2.5ms preprocess, 50.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.4ms
# Speed: 1.4ms preprocess, 55.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 44.0ms
# Speed: 2.0ms preprocess, 44.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.4ms
# Speed: 1.2ms preprocess, 52.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.9ms
# Speed: 1.5ms preprocess, 44.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 1.5ms preprocess, 53.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.9ms
# Speed: 2.3ms preprocess, 50.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.1ms
# Speed: 2.7ms preprocess, 45.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.8ms
# Speed: 2.3ms preprocess, 48.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.6ms
# Speed: 2.3ms preprocess, 44.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 2.0ms preprocess, 48.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.7ms
# Speed: 2.0ms preprocess, 45.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.4ms
# Speed: 2.5ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.2ms
# Speed: 1.5ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.1ms
# Speed: 2.4ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.7ms
# Speed: 2.0ms preprocess, 47.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.4ms
# Speed: 1.0ms preprocess, 46.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.0ms
# Speed: 2.1ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 2.0ms preprocess, 45.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.9ms
# Speed: 1.5ms preprocess, 46.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.6ms
# Speed: 1.0ms preprocess, 50.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.5ms
# Speed: 1.4ms preprocess, 45.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.1ms
# Speed: 1.0ms preprocess, 48.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.4ms preprocess, 46.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 49.3ms
# Speed: 2.1ms preprocess, 49.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.6ms
# Speed: 2.1ms preprocess, 51.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 1.0ms preprocess, 45.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 42.2ms
# Speed: 1.5ms preprocess, 42.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 42.5ms
# Speed: 2.0ms preprocess, 42.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 49.1ms
# Speed: 2.0ms preprocess, 49.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 50.6ms
# Speed: 1.0ms preprocess, 50.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.0ms
# Speed: 2.0ms preprocess, 43.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.1ms
# Speed: 1.6ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 45.8ms
# Speed: 1.5ms preprocess, 45.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 44.5ms
# Speed: 1.6ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 43.8ms
# Speed: 2.0ms preprocess, 43.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 53.4ms
# Speed: 1.0ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 42.8ms
# Speed: 1.4ms preprocess, 42.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 48.2ms
# Speed: 2.2ms preprocess, 48.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 45.1ms
# Speed: 2.0ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 49.3ms
# Speed: 2.1ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 48.2ms
# Speed: 1.4ms preprocess, 48.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 46.5ms
# Speed: 1.0ms preprocess, 46.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 45.6ms
# Speed: 1.5ms preprocess, 45.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 43.6ms
# Speed: 0.5ms preprocess, 43.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 42.2ms
# Speed: 1.4ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 42.8ms
# Speed: 1.0ms preprocess, 42.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 39.9ms
# Speed: 2.5ms preprocess, 39.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 traffic light, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.1ms
# Speed: 2.0ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 42.3ms
# Speed: 1.5ms preprocess, 42.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 42.8ms
# Speed: 1.0ms preprocess, 42.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 46.0ms
# Speed: 2.1ms preprocess, 46.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 41.7ms
# Speed: 2.0ms preprocess, 41.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 43.4ms
# Speed: 1.4ms preprocess, 43.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 2 traffic lights, 44.6ms
# Speed: 2.0ms preprocess, 44.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 traffic lights, 48.0ms
# Speed: 1.5ms preprocess, 48.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 traffic light, 55.4ms
# Speed: 2.0ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.2ms
# Speed: 1.1ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.0ms
# Speed: 1.6ms preprocess, 48.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.2ms
# Speed: 2.0ms preprocess, 46.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.0ms preprocess, 45.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 2.0ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 2.0ms preprocess, 42.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.0ms
# Speed: 1.5ms preprocess, 45.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 2.0ms preprocess, 40.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 42.2ms
# Speed: 1.5ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 44.2ms
# Speed: 2.0ms preprocess, 44.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 45.3ms
# Speed: 1.2ms preprocess, 45.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 42.6ms
# Speed: 1.0ms preprocess, 42.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 46.4ms
# Speed: 2.0ms preprocess, 46.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 46.6ms
# Speed: 2.0ms preprocess, 46.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 46.4ms
# Speed: 3.0ms preprocess, 46.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 47.9ms
# Speed: 2.0ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 46.3ms
# Speed: 1.0ms preprocess, 46.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.7ms
# Speed: 2.1ms preprocess, 49.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 48.6ms
# Speed: 1.3ms preprocess, 48.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 46.6ms
# Speed: 2.0ms preprocess, 46.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 45.7ms
# Speed: 1.0ms preprocess, 45.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 45.2ms
# Speed: 2.0ms preprocess, 45.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 43.9ms
# Speed: 1.1ms preprocess, 43.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 43.0ms
# Speed: 2.5ms preprocess, 43.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 45.0ms
# Speed: 2.1ms preprocess, 45.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 42.9ms
# Speed: 2.0ms preprocess, 42.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 56.3ms
# Speed: 1.5ms preprocess, 56.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 45.0ms
# Speed: 2.1ms preprocess, 45.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 44.2ms
# Speed: 1.0ms preprocess, 44.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 47.9ms
# Speed: 2.0ms preprocess, 47.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 43.7ms
# Speed: 1.5ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 44.1ms
# Speed: 2.5ms preprocess, 44.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.0ms
# Speed: 1.0ms preprocess, 49.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 47.9ms
# Speed: 2.4ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 48.2ms
# Speed: 1.0ms preprocess, 48.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.9ms
# Speed: 2.0ms preprocess, 50.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.3ms
# Speed: 1.1ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
