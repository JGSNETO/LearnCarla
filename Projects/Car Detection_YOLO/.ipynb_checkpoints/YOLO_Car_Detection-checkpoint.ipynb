# %%
import cv2
from ultralytics import YOLO
import carla
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load YOLOv8 model
model = YOLO("yolov8n.pt")

# %%
client = carla.Client('localhost', 2000)

# %%
world = client.get_world()

# %%
spawn_points = world.get_map().get_spawn_points()

# %%
bp_lib = world.get_blueprint_library()

for vehicle in bp_lib.filter('vehicle'):
    print(vehicle.id)
# Out:
# vehicle.audi.a2
# vehicle.nissan.micra
# vehicle.audi.tt
# vehicle.mercedes.coupe_2020
# vehicle.bmw.grandtourer
# vehicle.harley-davidson.low_rider
# vehicle.ford.ambulance
# vehicle.micro.microlino
# vehicle.carlamotors.firetruck
# vehicle.carlamotors.carlacola
# vehicle.carlamotors.european_hgv
# vehicle.ford.mustang
# vehicle.chevrolet.impala
# vehicle.lincoln.mkz_2020
# vehicle.citroen.c3
# vehicle.dodge.charger_police
# vehicle.nissan.patrol
# vehicle.jeep.wrangler_rubicon
# vehicle.mini.cooper_s
# vehicle.mercedes.coupe
# vehicle.dodge.charger_2020
# vehicle.ford.crown
# vehicle.seat.leon
# vehicle.toyota.prius
# vehicle.yamaha.yzf
# vehicle.kawasaki.ninja
# vehicle.bh.crossbike
# vehicle.mitsubishi.fusorosa
# vehicle.tesla.model3
# vehicle.gazelle.omafiets
# vehicle.tesla.cybertruck
# vehicle.diamondback.century
# vehicle.mercedes.sprinter
# vehicle.audi.etron
# vehicle.volkswagen.t2
# vehicle.lincoln.mkz_2017
# vehicle.dodge.charger_police_2020
# vehicle.vespa.zx125
# vehicle.mini.cooper_s_2021
# vehicle.nissan.patrol_2021
# vehicle.volkswagen.t2_2021

# %%
vehicle_bp = world.get_blueprint_library().filter('*cybertruck*')
start_point = spawn_points[0]
vehicle = world.try_spawn_actor(vehicle_bp[0], start_point)

# %%
# Camera Pos
CAMERA_POS_Z = 3
CAMERA_POS_X = 0

camera_bp = world.get_blueprint_library().find('sensor.camera.rgb')
camera_bp.set_attribute('image_size_x', '650')
camera_bp.set_attribute('image_size_y', '360')

camera_init_trans = carla.Transform(carla.Location(z=CAMERA_POS_Z, x = CAMERA_POS_X)) # Define the camera initial position and orientation
camera = world.spawn_actor(camera_bp, camera_init_trans, attach_to = vehicle) # Add the camera into the simulation

def camera_callback(image, data_dict): # Process each frame of data from the camera. 
    data_dict['image'] = np.reshape(np.copy(image.raw_data), (image.height, image.width, 4))
'''
 Retrieve the camera resolution that we set earlier and convert it to an integer so it can be used to initialize an array.
'''
image_w = camera_bp.get_attribute('image_size_x').as_int() 
image_h = camera_bp.get_attribute('image_size_y').as_int()
'''
Create a data structure (camera_data) to store the camera image data in a format that's easily accessible and modifiable during the simulation. 
'''
camera_data = {'image' : np.zeros((image_h, image_w,4))}
camera.listen(lambda image: camera_callback(image, camera_data)) # Open live stream from the camera

# %%
vehicle.set_autopilot(True)

# %%
while True:
    world.tick()
    if cv2.waitKey(1) == ord('q'):
        quit = True
        break
    image = camera_data['image']
    gray_frame = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray_frame_3ch = cv2.cvtColor(gray_frame, cv2.COLOR_GRAY2BGR)
    # Performs inference on the current frame
    results = model(gray_frame_3ch)

    # Filter results for cars only)
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls)
            if class_id == 2: # Class ID 2 is 'car' in COCO
                x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())  # Get bounding box coordinates
                confidence = box.conf[0] # Confidence score
                # Draw the bouding vox aroung the detected car
                cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Green box
                label = f'Car {confidence:.2f}'
                cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    cv2.imshow('Car detecion Camera', image)

cv2.destroyAllWindows()
camera.stop()
for actor in world.get_actors().filter('*vehicle*'):
    actor.destroy()
for sensor in world.get_actors().filter('*sensor*'):
    sensor.destroy()
# Out:
# 0: 384x640 3 cars, 98.5ms
# Speed: 4.4ms preprocess, 98.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 80.9ms
# Speed: 3.5ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 1 traffic light, 56.3ms
# Speed: 2.0ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 1 traffic light, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 1 traffic light, 66.1ms
# Speed: 1.0ms preprocess, 66.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 59.2ms
# Speed: 2.1ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 54.9ms
# Speed: 2.0ms preprocess, 54.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 54.8ms
# Speed: 2.5ms preprocess, 54.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 61.1ms
# Speed: 1.0ms preprocess, 61.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 1 traffic light, 45.4ms
# Speed: 2.1ms preprocess, 45.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 1 traffic light, 68.1ms
# Speed: 1.5ms preprocess, 68.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 1 traffic light, 62.4ms
# Speed: 2.0ms preprocess, 62.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 1 traffic light, 63.8ms
# Speed: 1.3ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 53.7ms
# Speed: 2.0ms preprocess, 53.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 55.1ms
# Speed: 1.1ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.8ms
# Speed: 1.0ms preprocess, 56.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 49.2ms
# Speed: 2.0ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 51.9ms
# Speed: 2.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 1 truck, 49.4ms
# Speed: 1.0ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 54.4ms
# Speed: 2.0ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 62.8ms
# Speed: 1.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 57.3ms
# Speed: 2.1ms preprocess, 57.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 48.2ms
# Speed: 1.1ms preprocess, 48.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 48.7ms
# Speed: 1.0ms preprocess, 48.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 64.1ms
# Speed: 1.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 67.4ms
# Speed: 1.0ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 65.8ms
# Speed: 2.0ms preprocess, 65.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 60.7ms
# Speed: 2.0ms preprocess, 60.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 59.1ms
# Speed: 1.0ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 57.9ms
# Speed: 1.1ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 48.3ms
# Speed: 1.5ms preprocess, 48.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 67.3ms
# Speed: 2.0ms preprocess, 67.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 76.7ms
# Speed: 1.5ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 60.7ms
# Speed: 6.0ms preprocess, 60.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 56.2ms
# Speed: 1.4ms preprocess, 56.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 66.2ms
# Speed: 1.0ms preprocess, 66.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 traffic light, 52.7ms
# Speed: 1.0ms preprocess, 52.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 59.1ms
# Speed: 2.5ms preprocess, 59.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 64.2ms
# Speed: 1.0ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 64.4ms
# Speed: 1.0ms preprocess, 64.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 48.5ms
# Speed: 2.0ms preprocess, 48.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 62.3ms
# Speed: 2.0ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 traffic light, 61.9ms
# Speed: 3.0ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 63.3ms
# Speed: 1.0ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 61.7ms
# Speed: 1.0ms preprocess, 61.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 58.0ms
# Speed: 1.5ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 71.0ms
# Speed: 1.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 71.0ms
# Speed: 0.5ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 1 train, 65.6ms
# Speed: 2.5ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 60.7ms
# Speed: 1.0ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 63.1ms
# Speed: 1.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bus, 61.6ms
# Speed: 2.5ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 73.2ms
# Speed: 1.5ms preprocess, 73.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 63.1ms
# Speed: 2.5ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 66.9ms
# Speed: 2.0ms preprocess, 66.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 54.8ms
# Speed: 2.3ms preprocess, 54.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 66.7ms
# Speed: 3.0ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 buss, 60.2ms
# Speed: 1.0ms preprocess, 60.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 buss, 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 50.0ms
# Speed: 1.5ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 64.6ms
# Speed: 2.0ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 traffic light, 61.2ms
# Speed: 1.0ms preprocess, 61.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 traffic light, 83.5ms
# Speed: 2.5ms preprocess, 83.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 57.3ms
# Speed: 1.2ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 56.4ms
# Speed: 1.4ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 56.4ms
# Speed: 4.5ms preprocess, 56.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 traffic light, 56.9ms
# Speed: 1.0ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 69.1ms
# Speed: 1.0ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 56.0ms
# Speed: 1.5ms preprocess, 56.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 traffic light, 60.7ms
# Speed: 1.5ms preprocess, 60.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 traffic light, 58.7ms
# Speed: 1.2ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 traffic light, 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 traffic light, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 traffic light, 65.6ms
# Speed: 1.0ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 74.9ms
# Speed: 2.0ms preprocess, 74.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 72.2ms
# Speed: 1.0ms preprocess, 72.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 69.4ms
# Speed: 3.0ms preprocess, 69.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 65.2ms
# Speed: 1.0ms preprocess, 65.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 72.1ms
# Speed: 1.5ms preprocess, 72.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 67.9ms
# Speed: 3.0ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 traffic light, 86.4ms
# Speed: 1.5ms preprocess, 86.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 67.1ms
# Speed: 3.0ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 73.2ms
# Speed: 1.0ms preprocess, 73.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 2 traffic lights, 59.5ms
# Speed: 1.5ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 1 traffic light, 54.0ms
# Speed: 2.5ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 70.6ms
# Speed: 2.0ms preprocess, 70.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 1 traffic light, 60.9ms
# Speed: 1.0ms preprocess, 60.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 3 traffic lights, 65.1ms
# Speed: 2.0ms preprocess, 65.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 2 traffic lights, 71.4ms
# Speed: 1.5ms preprocess, 71.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 1 traffic light, 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bus, 1 traffic light, 1 clock, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 clock, 56.7ms
# Speed: 2.1ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
