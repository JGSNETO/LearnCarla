# %%
import cv2
from ultralytics import YOLO
import carla
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load YOLOv8 model
model = YOLO("yolov8n.pt")

# %%
client = carla.Client('localhost', 2000)

# %%
world = client.get_world()

# %%
spawn_points = world.get_map().get_spawn_points()

# %%
bp_lib = world.get_blueprint_library()

for vehicle in bp_lib.filter('vehicle'):
    print(vehicle.id)
# Out:
# vehicle.audi.a2
# vehicle.nissan.micra
# vehicle.audi.tt
# vehicle.mercedes.coupe_2020
# vehicle.bmw.grandtourer
# vehicle.harley-davidson.low_rider
# vehicle.ford.ambulance
# vehicle.micro.microlino
# vehicle.carlamotors.firetruck
# vehicle.carlamotors.carlacola
# vehicle.carlamotors.european_hgv
# vehicle.ford.mustang
# vehicle.chevrolet.impala
# vehicle.lincoln.mkz_2020
# vehicle.citroen.c3
# vehicle.dodge.charger_police
# vehicle.nissan.patrol
# vehicle.jeep.wrangler_rubicon
# vehicle.mini.cooper_s
# vehicle.mercedes.coupe
# vehicle.dodge.charger_2020
# vehicle.ford.crown
# vehicle.seat.leon
# vehicle.toyota.prius
# vehicle.yamaha.yzf
# vehicle.kawasaki.ninja
# vehicle.bh.crossbike
# vehicle.mitsubishi.fusorosa
# vehicle.tesla.model3
# vehicle.gazelle.omafiets
# vehicle.tesla.cybertruck
# vehicle.diamondback.century
# vehicle.mercedes.sprinter
# vehicle.audi.etron
# vehicle.volkswagen.t2
# vehicle.lincoln.mkz_2017
# vehicle.dodge.charger_police_2020
# vehicle.vespa.zx125
# vehicle.mini.cooper_s_2021
# vehicle.nissan.patrol_2021
# vehicle.volkswagen.t2_2021

# %%
vehicle_bp = world.get_blueprint_library().filter('*cybertruck*')
start_point = spawn_points[0]
vehicle_mine = world.try_spawn_actor(vehicle_bp[0], start_point)

# %%
vehicles = []

vehicle_bps = bp_lib.filter("vehicle.*")

for i, spawn_point in enumerate(spawn_points[:100]):
    vehicle_bp = vehicle_bps[i % len(vehicle_bps)]

    vehicle = world.try_spawn_actor(vehicle_bp, spawn_point)

    if vehicle:
        vehicles.append(vehicle)

print(f"Spawned {len(vehicles)} vehicles")
# Out:
# Spawned 99 vehicles

# %%
traffic_manager = client.get_trafficmanager()

for vehicle in vehicles:
    vehicle.set_autopilot(True, traffic_manager.get_port())

print("Autopilot enabled")
# Out:
# Autopilot enabled

# %%
# Camera Pos
CAMERA_POS_Z = 3
CAMERA_POS_X = 0

camera_bp = world.get_blueprint_library().find('sensor.camera.rgb')
camera_bp.set_attribute('image_size_x', '650')
camera_bp.set_attribute('image_size_y', '360')

camera_init_trans = carla.Transform(carla.Location(z=CAMERA_POS_Z, x = CAMERA_POS_X)) # Define the camera initial position and orientation
camera = world.spawn_actor(camera_bp, camera_init_trans, attach_to = vehicle) # Add the camera into the simulation

def camera_callback(image, data_dict): # Process each frame of data from the camera. 
    data_dict['image'] = np.reshape(np.copy(image.raw_data), (image.height, image.width, 4))
'''
 Retrieve the camera resolution that we set earlier and convert it to an integer so it can be used to initialize an array.
'''
image_w = camera_bp.get_attribute('image_size_x').as_int() 
image_h = camera_bp.get_attribute('image_size_y').as_int()
'''
Create a data structure (camera_data) to store the camera image data in a format that's easily accessible and modifiable during the simulation. 
'''
camera_data = {'image' : np.zeros((image_h, image_w,4))}
camera.listen(lambda image: camera_callback(image, camera_data)) # Open live stream from the camera

# %%
vehicle.set_autopilot(True)

# %%
while True:
    world.tick()
    if cv2.waitKey(1) == ord('q'):
        quit = True
        break
    image = camera_data['image']
    gray_frame = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray_frame_3ch = cv2.cvtColor(gray_frame, cv2.COLOR_GRAY2BGR)
    # Performs inference on the current frame
    results = model(gray_frame_3ch)

    # Filter results for cars only)
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls)
            if class_id == 2: # Class ID 2 is 'car' in COCO
                x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())  # Get bounding box coordinates
                confidence = box.conf[0] # Confidence score
                # Draw the bouding vox aroung the detected car
                cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Green box
                label = f'Car {confidence:.2f}'
                cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    cv2.imshow('Car detecion Camera', image)

cv2.destroyAllWindows()
camera.stop()
for actor in world.get_actors().filter('*vehicle*'):
    actor.destroy()
for sensor in world.get_actors().filter('*sensor*'):
    sensor.destroy()
# Out:
# 0: 384x640 1 person, 1 bicycle, 1 car, 2 buss, 1 truck, 118.0ms
# Speed: 3.8ms preprocess, 118.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bicycles, 4 cars, 1 bus, 109.6ms
# Speed: 3.6ms preprocess, 109.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 83.1ms
# Speed: 2.7ms preprocess, 83.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 1 truck, 78.8ms
# Speed: 2.8ms preprocess, 78.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 1 truck, 85.9ms
# Speed: 2.6ms preprocess, 85.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 72.5ms
# Speed: 3.4ms preprocess, 72.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 73.4ms
# Speed: 2.5ms preprocess, 73.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 69.3ms
# Speed: 2.6ms preprocess, 69.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 72.5ms
# Speed: 3.3ms preprocess, 72.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 1 truck, 74.4ms
# Speed: 2.1ms preprocess, 74.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 80.7ms
# Speed: 2.2ms preprocess, 80.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 83.6ms
# Speed: 2.8ms preprocess, 83.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 66.5ms
# Speed: 2.6ms preprocess, 66.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 1 truck, 91.9ms
# Speed: 2.7ms preprocess, 91.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 1 truck, 86.7ms
# Speed: 3.1ms preprocess, 86.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 88.0ms
# Speed: 2.9ms preprocess, 88.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 76.8ms
# Speed: 2.9ms preprocess, 76.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 74.5ms
# Speed: 2.7ms preprocess, 74.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 1 traffic light, 76.9ms
# Speed: 2.9ms preprocess, 76.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 73.6ms
# Speed: 2.7ms preprocess, 73.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 71.6ms
# Speed: 2.7ms preprocess, 71.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 78.5ms
# Speed: 2.6ms preprocess, 78.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 73.7ms
# Speed: 2.8ms preprocess, 73.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 75.2ms
# Speed: 2.5ms preprocess, 75.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 1 truck, 99.3ms
# Speed: 2.4ms preprocess, 99.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 73.3ms
# Speed: 2.9ms preprocess, 73.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 67.0ms
# Speed: 3.0ms preprocess, 67.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bus, 69.1ms
# Speed: 3.1ms preprocess, 69.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 motorcycle, 1 bus, 64.6ms
# Speed: 2.0ms preprocess, 64.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 1 car, 1 bus, 70.6ms
# Speed: 2.3ms preprocess, 70.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 1 car, 1 bus, 70.3ms
# Speed: 3.0ms preprocess, 70.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 2 cars, 1 motorcycle, 1 bus, 1 parking meter, 66.7ms
# Speed: 2.5ms preprocess, 66.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 1 car, 2 buss, 1 train, 65.4ms
# Speed: 3.0ms preprocess, 65.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 3 cars, 2 buss, 63.9ms
# Speed: 2.9ms preprocess, 63.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 68.1ms
# Speed: 2.8ms preprocess, 68.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 bus, 85.3ms
# Speed: 3.0ms preprocess, 85.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 66.6ms
# Speed: 3.0ms preprocess, 66.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 buss, 65.0ms
# Speed: 2.4ms preprocess, 65.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 buss, 1 truck, 1 fire hydrant, 67.9ms
# Speed: 2.6ms preprocess, 67.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 buss, 83.4ms
# Speed: 2.8ms preprocess, 83.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 2 buss, 1 fire hydrant, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 buss, 65.2ms
# Speed: 2.8ms preprocess, 65.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 2 buss, 65.9ms
# Speed: 2.4ms preprocess, 65.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 2 buss, 66.3ms
# Speed: 3.0ms preprocess, 66.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 2 buss, 65.6ms
# Speed: 2.4ms preprocess, 65.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 buss, 66.4ms
# Speed: 2.4ms preprocess, 66.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 72.1ms
# Speed: 2.8ms preprocess, 72.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 69.8ms
# Speed: 3.0ms preprocess, 69.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 79.6ms
# Speed: 3.0ms preprocess, 79.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 69.7ms
# Speed: 2.5ms preprocess, 69.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 1 bus, 1 fire hydrant, 65.8ms
# Speed: 3.1ms preprocess, 65.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 68.0ms
# Speed: 2.7ms preprocess, 68.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 67.4ms
# Speed: 2.6ms preprocess, 67.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 65.7ms
# Speed: 3.1ms preprocess, 65.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 67.4ms
# Speed: 2.5ms preprocess, 67.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 69.2ms
# Speed: 2.5ms preprocess, 69.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 67.5ms
# Speed: 2.9ms preprocess, 67.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 car, 1 bus, 66.1ms
# Speed: 2.5ms preprocess, 66.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 67.3ms
# Speed: 2.6ms preprocess, 67.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 66.6ms
# Speed: 3.0ms preprocess, 66.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 69.7ms
# Speed: 2.5ms preprocess, 69.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 68.4ms
# Speed: 2.7ms preprocess, 68.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 66.7ms
# Speed: 2.4ms preprocess, 66.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bus, 67.4ms
# Speed: 3.1ms preprocess, 67.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 car, 1 bus, 69.3ms
# Speed: 2.9ms preprocess, 69.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 67.3ms
# Speed: 2.7ms preprocess, 67.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 67.2ms
# Speed: 3.2ms preprocess, 67.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 86.4ms
# Speed: 3.1ms preprocess, 86.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 72.6ms
# Speed: 2.8ms preprocess, 72.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 63.4ms
# Speed: 3.3ms preprocess, 63.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
